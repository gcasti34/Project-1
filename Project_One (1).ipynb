# %% [markdown]
#  I got my dataset from the dataset google drive. It is roller_coasters.csv. I found this dataset to be very interesting due to the 1087 rows and 56 columns which at the end of this project won't use all the columns and rows. This dataset has variables such as speed,cost,type of material, and height. These variables are self explainatory however will need some data wrangling to make them possible to mantipulate correctly. One goals for this project is   to explore how the type of material of a roller coaster can impact its overall speed? I also want to know how fast median/range of the speeds of roller coasters? One fun question is highest inversions in all the rollercoaster?

# %% [markdown]
# Loading in the dataset for the Project

# %%
import pandas as pd
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir("/content/drive/My Drive/Colab Notebooks")
rollercoasters = pd.read_csv("/content/drive/MyDrive/Google colab/roller_coasters.csv")
print(rollercoasters)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                                 coaster_name                Length  \
# 0                         Switchback Railway        600 ft (180 m)
# 1                          Flip Flap Railway                   NaN
# 2     Switchback Railway (Euclid Beach Park)                   NaN
# 3               Loop the Loop (Coney Island)                   NaN
# 4               Loop the Loop (Young's Pier)                   NaN
# ...                                      ...                   ...
# 1082                 American Dreier Looping    3,444 ft (1,050 m)
# 1083               Pantheon (roller coaster)    3,328 ft (1,014 m)
# 1084               Tron Lightcycle Power Run  3,169.3 ft (966.0 m)
# 1085                                 Tumbili        770 ft (230 m)
# 1086          Wonder Woman Flight of Courage    3,300 ft (1,000 m)
#
#                         Speed                        Location  \
# 0            6 mph (9.7 km/h)                    Coney Island
# 1                         NaN                   Sea Lion Park
# 2                         NaN  Cleveland, Ohio, United States
# 3                         NaN                           Other
# 4                         NaN                           Other
# ...                       ...                             ...
# 1082         53 mph (85 km/h)                           Other
# 1083        73 mph (117 km/h)      Busch Gardens Williamsburg
# 1084  59.3[1] mph (95.4 km/h)                           Other
# 1085         34 mph (55 km/h)                  Kings Dominion
# 1086         58 mph (93 km/h)        Six Flags Magic Mountain
#
#                   Status   Opening date                                  Type  \
# 0                Removed  June 16, 1884                                  Wood
# 1                Removed           1895                                  Wood
# 2                 Closed            NaN                                 Other
# 3                Removed           1901                                 Steel
# 4                Removed           1901                                 Steel
# ...                  ...            ...                                   ...
# 1082                 NaN            NaN                                 Steel
# 1083  Under construction           2022                      Steel – Launched
# 1084                 NaN  June 16, 2016                      Steel – Launched
# 1085  Under construction            NaN  Steel – 4th Dimension – Wing Coaster
# 1086  Under construction           2022                   Steel – Single-rail
#
#                      Manufacturer Height restriction  \
# 0          LaMarcus Adna Thompson                NaN
# 1                    Lina Beecher                NaN
# 2                             NaN                NaN
# 3                  Edwin Prescott                NaN
# 4                  Edwin Prescott                NaN
# ...                           ...                ...
# 1082            Anton Schwarzkopf     55 in (140 cm)
# 1083                      Intamin                NaN
# 1084                       Vekoma   4[2] ft (122 cm)
# 1085    S&S – Sansei Technologies                NaN
# 1086  Rocky Mountain Construction                NaN
#
#                          Model  ...     speed1     speed2 speed1_value  \
# 0                  Lift Packed  ...     6 mph    9.7 km/h          6.0
# 1                          NaN  ...        NaN        NaN          NaN
# 2                          NaN  ...        NaN        NaN          NaN
# 3                          NaN  ...        NaN        NaN          NaN
# 4                          NaN  ...        NaN        NaN          NaN
# ...                        ...  ...        ...        ...          ...
# 1082                       NaN  ...    53 mph     85 km/h         53.0
# 1083             Blitz Coaster  ...    73 mph    117 km/h         73.0
# 1084  Motorbike roller coaster  ...  59.3 mph   95.4 km/h         59.3
# 1085              4D Free Spin  ...    34 mph     55 km/h         34.0
# 1086           Raptor – Custom  ...    58 mph     93 km/h         58.0
#
#      speed1_unit speed_mph height_value height_unit height_ft  \
# 0            mph       6.0         50.0          ft       NaN
# 1            NaN       NaN          NaN         NaN       NaN
# 2            NaN       NaN          NaN         NaN       NaN
# 3            NaN       NaN          NaN         NaN       NaN
# 4            NaN       NaN          NaN         NaN       NaN
# ...          ...       ...          ...         ...       ...
# 1082         mph      53.0        111.0          ft       NaN
# 1083         mph      73.0        178.0          ft       NaN
# 1084         mph      59.3         78.1          ft       NaN
# 1085         mph      34.0        112.0          ft       NaN
# 1086         mph      58.0        131.0          ft       NaN
#
#      Inversions_clean Gforce_clean
# 0                   0          2.9
# 1                   1         12.0
# 2                   0          NaN
# 3                   1          NaN
# 4                   1          NaN
# ...               ...          ...
# 1082                3          4.7
# 1083                2          NaN
# 1084                0          4.0
# 1085                0          NaN
# 1086                3          NaN
#
# [1087 rows x 56 columns]

# %%
rollercoasters['Type'].unique()
# Out:
# array(['Wood', 'Other', 'Steel', 'Wood\xa0– Side friction',
#        'Wood\xa0– Shuttle', 'Wood\xa0– Racing', 'Wood\xa0– Out and back',
#        'Wood\xa0– Wild Mouse', 'Steel\xa0– Mine Train',
#        'Steel\xa0– Dueling', 'Steel\xa0– Kiddie', 'Steel\xa0– Enclosed',
#        'Steel\xa0– Wild Mouse', 'Steel\xa0– Dual-tracked\xa0– Enclosed',
#        'Steel\xa0– Junior', 'Steel\xa0– Shuttle', 'Steel\xa0– Racing',
#        'Steel\xa0– Dueling\xa0– Racing',
#        'Steel\xa0– Launched\xa0– Shuttle', 'Steel\xa0– Stand-up',
#        'Steel\xa0– Shuttle\xa0– Launched', 'Steel\xa0– Suspended',
#        'Steel\xa0– Powered\xa0– Mine Train',
#        'Steel\xa0– Powered\xa0– Virtual reality', 'Steel\xa0– Pipeline',
#        'Steel\xa0– Enclosed\xa0– Bobsled', 'Steel\xa0– Twister',
#        'Steel\xa0– Bobsled', 'Steel\xa0– Wild Mouse\xa0– Enclosed',
#        'Steel\xa0– Powered', 'Wood\xa0– Family', 'Steel\xa0– Boomerang',
#        'Steel\xa0– Shuttle\xa0– Boomerang',
#        'Steel\xa0– Boomerang\xa0– Shuttle', 'Steel\xa0– Indoor',
#        'Steel\xa0– Floorless Coaster', 'Steel\xa0– Family',
#        'Steel\xa0– Inverted', 'Steel\xa0– Junior\xa0– Powered', '– Steel',
#        'Steel junior roller coaster', 'Steel\xa0– Powered\xa0– Indoor',
#        'Steel\xa0– Launched', 'Steel\xa0– Launched\xa0– Enclosed',
#        'Steel\xa0– Shuttle\xa0– boomerang', 'Steel\xa0– spinning',
#        'Steel\xa0– Flying',
#        'Steel\xa0– Launched\xa0– Shuttle\xa0– Dueling',
#        'Steel\xa0– Wild Mouse\xa0– Racing', 'Steel\xa0– Dive Coaster',
#        'Steel\xa0– Inverted\xa0– Launched',
#        'Steel\xa0– Inverted\xa0– Dueling',
#        'Steel\xa0– Enclosed\xa0– Spinning', 'Steel\xa0– Wooden',
#        'Steel\xa0– Enclosed\xa0– Launched',
#        'Steel\xa0– Suspended\xa0– Family',
#        'Steel\xa0– Wild Mouse\xa0– Family',
#        'Wood\xa0– Racing\xa0– Dueling',
#        'Steel\xa0– Family\xa0– Wild Mouse',
#        'Steel\xa0– Family\xa0– Inverted',
#        'Steel\xa0– Launched\xa0– Inverted',
#        'Steel\xa0– Suspended Family Coaster', 'Wood\xa0– Steel',
#        'Steel\xa0– Spinning\xa0– Wild Mouse',
#        'Steel\xa0– Spinning\xa0– Indoor', 'Steel\xa0– 4th Dimension',
#        'Steel\xa0– Spinning', 'Steel\xa0– Inverted\xa0– Family',
#        'Steel\xa0– Euro-Fighter', 'Steel\xa0– Motorbike\xa0– Launched',
#        'Steel\xa0– Wild Mouse\xa0– Spinning', 'Wood\xa0– Twister',
#        'Steel\xa0– Spinning\xa0– Enclosed',
#        'Steel\xa0– Launched\xa0– Motorbike',
#        'Steel\xa0– Euro-Fighter\xa0– Indoor',
#        'Steel\xa0– Launched\xa0– Euro-Fighter',
#        'Steel\xa0– Dueling\xa0– Launched',
#        'Steel\xa0– Launched\xa0– Dueling',
#        'Steel\xa0– Junior\xa0– Boomerang',
#        'Steel\xa0– Family\xa0– Enclosed', 'Steel\xa0– Wing Coaster',
#        'Wood\xa0– Terrain', 'Steel\xa0– Mine Train\xa0– Launched',
#        'Steel\xa0– Shuttle\xa0– Inverted',
#        'Steel\xa0– Launched\xa0– Family', 'Wood\xa0– Bobsled',
#        'Steel\xa0– Mountain coaster', 'Steel\xa0– Inverted\xa0– Powered',
#        'Steel\xa0– Family\xa0– Launched',
#        'Steel\xa0– Wing Coaster\xa0– Launched',
#        'Steel\xa0– 4th Dimension\xa0– Wing Coaster',
#        'Steel\xa0– Spinning\xa0– Launched',
#        'Steel\xa0– Family\xa0– Indoor',
#        'Steel\xa0– Shuttle\xa0– Enclosed',
#        'Steel\xa0– Flying\xa0– Launched',
#        'Steel\xa0– Powered\xa0– Dual-tracked',
#        'Steel\xa0– Launched\xa0– Indoor', 'Steel\xa0– Single-rail'],
#       dtype=object)

# %%
rollercoasters['Type'] = rollercoasters['Type'].str.replace('\xa0', ' ', regex=True)

# %%
def clean_material(value):
    value = value.lower().replace('\xa0', ' ')
    if 'wood' in value:
        return 'Wood'
    elif 'steel' in value:
        return 'Steel'
    else:
        return 'Other'

rollercoasters['Type_Clean'] = rollercoasters['Type'].apply(clean_material)

# %%
print(rollercoasters['Type_Clean'].unique())
# Out:
# ['Wood' 'Other' 'Steel']

# %%
rollercoasters['Type_Clean'].value_counts()
# Out:
# Type_Clean
# Steel    815
# Wood     200
# Other     72
# Name: count, dtype: int64

# %%
rollercoasters.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model  ...    speed2  \
# 0  LaMarcus Adna Thompson                NaN  Lift Packed  ...  9.7 km/h
# 1            Lina Beecher                NaN          NaN  ...       NaN
# 2                     NaN                NaN          NaN  ...       NaN
# 3          Edwin Prescott                NaN          NaN  ...       NaN
# 4          Edwin Prescott                NaN          NaN  ...       NaN
#
#    speed1_value speed1_unit speed_mph height_value height_unit height_ft  \
# 0           6.0         mph       6.0         50.0          ft       NaN
# 1           NaN         NaN       NaN          NaN         NaN       NaN
# 2           NaN         NaN       NaN          NaN         NaN       NaN
# 3           NaN         NaN       NaN          NaN         NaN       NaN
# 4           NaN         NaN       NaN          NaN         NaN       NaN
#
#   Inversions_clean Gforce_clean Type_Clean
# 0                0          2.9       Wood
# 1                1         12.0       Wood
# 2                0          NaN      Other
# 3                1          NaN      Steel
# 4                1          NaN      Steel
#
# [5 rows x 57 columns]

# %%
rollercoasters.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# Fast Lane available               object
# Replaced                          object
# Track layout                      object
# Fastrack available                object
# Soft opening date.1               object
# Closing date                      object
# Opened                            object
# Replaced by                       object
# Website                           object
# Flash Pass Available              object
# Must transfer from wheelchair     object
# Theme                             object
# Single rider line available       object
# Restraint Style                   object
# Flash Pass available              object
# Acceleration                      object
# Restraints                        object
# Name                              object
# year_introduced                    int64
# latitude                         float64
# longitude                        float64
# Type_Main                         object
# opening_date_clean                object
# speed1                            object
# speed2                            object
# speed1_value                     float64
# speed1_unit                       object
# speed_mph                        float64
# height_value                     float64
# height_unit                       object
# height_ft                        float64
# Inversions_clean                   int64
# Gforce_clean                     float64
# Type_Clean                        object
# dtype: object

# %%
rollercoasters.isnull().sum()
# Out:
# coaster_name                        0
# Length                            134
# Speed                             150
# Location                            0
# Status                            213
# Opening date                      250
# Type                                0
# Manufacturer                       59
# Height restriction                256
# Model                             343
# Height                            122
# Inversions                        155
# Lift/launch system                292
# Cost                              705
# Trains                            369
# Park section                      600
# Duration                          322
# Capacity                          512
# G-force                           725
# Designer                          509
# Max vertical angle                730
# Drop                              593
# Soft opening date                 991
# Fast Lane available              1018
# Replaced                          914
# Track layout                      752
# Fastrack available               1068
# Soft opening date.1               991
# Closing date                      851
# Opened                           1060
# Replaced by                       999
# Website                          1000
# Flash Pass Available             1037
# Must transfer from wheelchair     981
# Theme                            1043
# Single rider line available      1006
# Restraint Style                  1065
# Flash Pass available             1041
# Acceleration                     1027
# Restraints                       1063
# Name                             1052
# year_introduced                     0
# latitude                          275
# longitude                         275
# Type_Main                           0
# opening_date_clean                250
# speed1                            150
# speed2                            152
# speed1_value                      150
# speed1_unit                       150
# speed_mph                         150
# height_value                      122
# height_unit                       122
# height_ft                         916
# Inversions_clean                    0
# Gforce_clean                      725
# Type_Clean                          0
# dtype: int64

# %% [markdown]
# Checking that cost has NAs

# %%
rollercoasters['Cost'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Cost, dtype: object

# %% [markdown]
# Dropping all the NAs for the Quantative Variables

# %%
Roller = rollercoasters.dropna(subset=['Length', 'Speed', 'Height','Cost'])
Roller.isnull().sum()
# Out:
# coaster_name                       0
# Length                             0
# Speed                              0
# Location                           0
# Status                            31
# Opening date                      31
# Type                               0
# Manufacturer                       4
# Height restriction                28
# Model                             79
# Height                             0
# Inversions                        23
# Lift/launch system                42
# Cost                               0
# Trains                            77
# Park section                     138
# Duration                          51
# Capacity                          93
# G-force                          182
# Designer                         145
# Max vertical angle               162
# Drop                             134
# Soft opening date                299
# Fast Lane available              313
# Replaced                         278
# Track layout                     213
# Fastrack available               340
# Soft opening date.1              299
# Closing date                     293
# Opened                           353
# Replaced by                      319
# Website                          314
# Flash Pass Available             339
# Must transfer from wheelchair    320
# Theme                            340
# Single rider line available      325
# Restraint Style                  350
# Flash Pass available             333
# Acceleration                     325
# Restraints                       344
# Name                             349
# year_introduced                    0
# latitude                          41
# longitude                         41
# Type_Main                          0
# opening_date_clean                31
# speed1                             0
# speed2                             0
# speed1_value                       0
# speed1_unit                        0
# speed_mph                          0
# height_value                       0
# height_unit                        0
# height_ft                        283
# Inversions_clean                   0
# Gforce_clean                     182
# Type_Clean                         0
# dtype: int64

# %% [markdown]
# Dropping two unecessary columns

# %%
Roller.drop(columns=['Gforce_clean','Single rider line available'])
Roller.head()
# Out:
#                              coaster_name              Length  \
# 13            Racer (1910 roller coaster)  4,500 ft (1,400 m)
# 22                Jack Rabbit (Kennywood)    2,132 ft (650 m)
# 26  Big Dipper (Blackpool Pleasure Beach)  3,300 ft (1,000 m)
# 29                           Giant Dipper    2,640 ft (800 m)
# 33               Big Dipper (Geauga Lake)    2,680 ft (820 m)
#
#                Speed                    Location     Status Opening date  \
# 13  40 mph (64 km/h)                   Kennywood  Operating         1927
# 22  45 mph (72 km/h)                   Kennywood  Operating         1920
# 26  40 mph (64 km/h)    Blackpool Pleasure Beach  Operating    23-Aug-23
# 29  55 mph (89 km/h)  Santa Cruz Beach Boardwalk  Operating    17-May-24
# 33  32 mph (51 km/h)                 Geauga Lake    Removed         1925
#
#                    Type       Manufacturer Height restriction  \
# 13        Wood – Racing       Charlie Mach     46 in (117 cm)
# 22                 Wood     Harry C. Baker     42 in (107 cm)
# 26  Wood – Out and back  William Strickler     46 in (117 cm)
# 29                 Wood       Arthur Looff     50 in (127 cm)
# 33                 Wood                NaN     48 in (122 cm)
#
#                           Model  ...   speed2  speed1_value speed1_unit  \
# 13                       Racing  ...  64 km/h          40.0         mph
# 22                          NaN  ...  72 km/h          45.0         mph
# 26  Wooden Out and back coaster  ...  64 km/h          40.0         mph
# 29                          NaN  ...  89 km/h          55.0         mph
# 33  Out and Back roller coaster  ...  51 km/h          32.0         mph
#
#    speed_mph height_value height_unit height_ft Inversions_clean Gforce_clean  \
# 13      40.0         72.5          ft       NaN                0          NaN
# 22      45.0         40.0          ft       NaN                0          NaN
# 26      40.0         65.0          ft       NaN                0          3.7
# 29      55.0         70.0          ft       NaN                0          NaN
# 33      32.0         65.0          ft       NaN                0          NaN
#
#    Type_Clean
# 13       Wood
# 22       Wood
# 26       Wood
# 29       Wood
# 33       Wood
#
# [5 rows x 57 columns]

# %% [markdown]
# Making sure all my variables I will use has no NAs

# %%
Roller.isnull().sum()
# Out:
# coaster_name                       0
# Length                             0
# Speed                              0
# Location                           0
# Status                            31
# Opening date                      31
# Type                               0
# Manufacturer                       4
# Height restriction                28
# Model                             79
# Height                             0
# Inversions                        23
# Lift/launch system                42
# Cost                               0
# Trains                            77
# Park section                     138
# Duration                          51
# Capacity                          93
# G-force                          182
# Designer                         145
# Max vertical angle               162
# Drop                             134
# Soft opening date                299
# Fast Lane available              313
# Replaced                         278
# Track layout                     213
# Fastrack available               340
# Soft opening date.1              299
# Closing date                     293
# Opened                           353
# Replaced by                      319
# Website                          314
# Flash Pass Available             339
# Must transfer from wheelchair    320
# Theme                            340
# Single rider line available      325
# Restraint Style                  350
# Flash Pass available             333
# Acceleration                     325
# Restraints                       344
# Name                             349
# year_introduced                    0
# latitude                          41
# longitude                         41
# Type_Main                          0
# opening_date_clean                31
# speed1                             0
# speed2                             0
# speed1_value                       0
# speed1_unit                        0
# speed_mph                          0
# height_value                       0
# height_unit                        0
# height_ft                        283
# Inversions_clean                   0
# Gforce_clean                     182
# Type_Clean                         0
# dtype: int64

# %% [markdown]
# Importing all the necessary Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(Roller.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 353 entries, 13 to 1081
# Data columns (total 57 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   coaster_name                   353 non-null    object
#  1   Length                         353 non-null    object
#  2   Speed                          353 non-null    object
#  3   Location                       353 non-null    object
#  4   Status                         322 non-null    object
#  5   Opening date                   322 non-null    object
#  6   Type                           353 non-null    object
#  7   Manufacturer                   349 non-null    object
#  8   Height restriction             325 non-null    object
#  9   Model                          274 non-null    object
#  10  Height                         353 non-null    object
#  11  Inversions                     330 non-null    float64
#  12  Lift/launch system             311 non-null    object
#  13  Cost                           353 non-null    object
#  14  Trains                         276 non-null    object
#  15  Park section                   215 non-null    object
#  16  Duration                       302 non-null    object
#  17  Capacity                       260 non-null    object
#  18  G-force                        171 non-null    object
#  19  Designer                       208 non-null    object
#  20  Max vertical angle             191 non-null    object
#  21  Drop                           219 non-null    object
#  22  Soft opening date              54 non-null     object
#  23  Fast Lane available            40 non-null     object
#  24  Replaced                       75 non-null     object
#  25  Track layout                   140 non-null    object
#  26  Fastrack available             13 non-null     object
#  27  Soft opening date.1            54 non-null     object
#  28  Closing date                   60 non-null     object
#  29  Opened                         0 non-null      object
#  30  Replaced by                    34 non-null     object
#  31  Website                        39 non-null     object
#  32  Flash Pass Available           14 non-null     object
#  33  Must transfer from wheelchair  33 non-null     object
#  34  Theme                          13 non-null     object
#  35  Single rider line available    28 non-null     object
#  36  Restraint Style                3 non-null      object
#  37  Flash Pass available           20 non-null     object
#  38  Acceleration                   28 non-null     object
#  39  Restraints                     9 non-null      object
#  40  Name                           4 non-null      object
#  41  year_introduced                353 non-null    int64
#  42  latitude                       312 non-null    float64
#  43  longitude                      312 non-null    float64
#  44  Type_Main                      353 non-null    object
#  45  opening_date_clean             322 non-null    object
#  46  speed1                         353 non-null    object
#  47  speed2                         353 non-null    object
#  48  speed1_value                   353 non-null    float64
#  49  speed1_unit                    353 non-null    object
#  50  speed_mph                      353 non-null    float64
#  51  height_value                   353 non-null    float64
#  52  height_unit                    353 non-null    object
#  53  height_ft                      70 non-null     float64
#  54  Inversions_clean               353 non-null    int64
#  55  Gforce_clean                   171 non-null    float64
#  56  Type_Clean                     353 non-null    object
# dtypes: float64(8), int64(2), object(47)
# memory usage: 160.0+ KB
# None

# %% [markdown]
# Three plots for my question

# %%
sns.boxplot(
    x='speed_mph',
    data=Roller,
    color='skyblue',
    fliersize=4,
    linewidth=2)
plt.title('Boxplot of Coaster Speeds', fontsize=14)
plt.xlabel('Speed (mph)', fontsize=12)
plt.show()

# %%
sns.barplot(x='Type_Clean', y='speed_mph', data=Roller)
plt.xticks(rotation=45)
plt.title('  Speed by Coaster Type', fontsize=16)
plt.xlabel('Coaster Type', fontsize=12)
plt.ylabel(' Speed (mph)', fontsize=12)

plt.show()

# %%
sns.set(style="whitegrid")

sns.histplot(Roller['Inversions_clean'], kde=True)
plt.title(' Distribution of Inversions (Upside Down Times)', fontsize=16)
plt.xlabel('Number of Inversions', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.show()

# %% [markdown]
# nonparametric inference of the Median for a quantitative variable in the
# dataset

# %%
sample_size = int(0.1 * len(Roller))
sample_data = Roller['speed_mph'].dropna().sample(n=sample_size, random_state=42)


n_bootstraps = 1000
boot_medians = np.empty(n_bootstraps)

for i in range(n_bootstraps):
    boot_sample = sample_data.sample(n=sample_size, replace=True)
    boot_medians[i] = np.median(boot_sample)


mean_of_medians = np.mean(boot_medians)
ci_lower = np.percentile(boot_medians, 2.5)
ci_upper = np.percentile(boot_medians, 97.5)


print(f"95% Confidence Interval for the Median Speed: [{ci_lower:.2f}, {ci_upper:.2f}]")

print(f"Mean of Bootstrapped Medians: {mean_of_medians:.2f}")
# Out:
# 95% Confidence Interval for the Median Speed: [50.00, 61.12]
# Mean of Bootstrapped Medians: 54.59

# %%
sns.histplot(boot_medians, bins=30, kde=True, color='skyblue')
plt.axvline(ci_lower, color='red', linestyle='--', label=f'2.5th Percentile: {ci_lower:.2f}')
plt.axvline(ci_upper, color='red', linestyle='--', label=f'97.5th Percentile: {ci_upper:.2f}')
plt.xlabel('Median Speed (mph)')
plt.ylabel('Frequency')
plt.title('Bootstrap Distribution of Median Coaster Speeds with 95% Confidence Interval')
plt.legend()
plt.show()
